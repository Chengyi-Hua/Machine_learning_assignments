# %% [markdown]
# # Code and output overview for the first graded assignment HWS 2025 - Machine Learning
# ### Chengyi Hua - ID 2117289 - MMDS
#
# This Jupyter Notebook consolidates all code, code results and figures developed throughout **Assignment 01** of the course *Machine Learning (ML25)*.
# It integrates the contents originally structured in multiple Python scripts (`a01_1.py` to `a01_6.py`) into a single, coherent document for readability.
#
# ### Please note, this is only the raw outputs. For interpretations and summaries, please switch to the report itself.
#
# All tasks from **Task 1 to Task 6** are included in sequence.
# - **Tasks 1, 2, and 5a** were direct implementation tasks and verified through execution consistency with provided comments.
# - **Tasks 3–6** form the analytical and interpretative sections, including experiments, model selection, data generation, and missing-data analysis.
#
# Each section includes:
# - The **corresponding Python implementation**
# - The **generated visual outputs**  (used and not used)
#
# This unified notebook therefore serves as the complete and reproducible submission artifact, containing all computational steps, results. Discussion and elaboration are given in the report itself.
